# %%
import requests

def fetch_html(url, output_file):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for HTTP errors
        with open(output_file, "w", encoding="utf-8") as f:
            f.write(response.text)
        print(f"Successfully fetched HTML and saved to {output_file}")
    except requests.exceptions.RequestException as e:
        print(f"Error fetching URL {url}: {e}")

website_url = "https://snielebock.github.io/mrpua/Sorter.html"
output_html_file = "page_content.html"
fetch_html(website_url, output_html_file )
# Out:
# Successfully fetched HTML and saved to page_content.html

# %%
import re
import json

def extract_papers_from_html(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        html_content = f.read()

    # Regex to find the JavaScript array 'objects'
    match = re.search(r"const objects = (.*?);\s*// Function to filter objects", html_content, re.DOTALL)

    papers_data = []
    if match:
        json_str = match.group(1).strip()
        try:
            data = json.loads(json_str)
            for item in data:
                papers_data.append({
                    'id': item.get('pID'),
                    'title': item.get('Title'),
                    'artifact_url': item.get('ArtifactURL'),
                    'doi_url': item.get('DOIURL')
                })
        except json.JSONDecodeError as e:
            print(f"JSON decoding error: {e}")
            # Provide more context for debugging
            start = max(0, e.pos - 50)
            end = e.pos + 50
            print(f"Problematic string part: ...{json_str[start:end]}...")
    else:
        print("Could not find the 'objects' JavaScript array in the HTML file.")

    return papers_data

if __name__ == "__main__":
    html_file = "page_content.html"
    papers = extract_papers_from_html(html_file)
    if papers:
        print(f"Successfully extracted {len(papers)} papers.")
        # Save the extracted data to a JSON file for further processing
        with open("papers_data.json", "w", encoding="utf-8") as f:
            json.dump(papers, f, indent=4)
        print("Saved paper data to papers_data.json")
    else:
        print("Failed to extract papers.")
# Out:
# Successfully extracted 189 papers.
# Saved paper data to papers_data.json

# %%
import json
import re

def score_paper(paper):
    score = 0
    notes = []

    artifact_url = paper.get("artifact_url", "").lower()
    artifact_url2 = paper.get("artifact_url2", "").lower() # Assuming a second artifact URL might exist

    # Helper to check if any of the URLs contain a keyword
    def url_contains(keyword):
        return keyword in artifact_url or keyword in artifact_url2

    # 1. Code & Environment (40 points)
    # 1.1 Code Availability & Quality
    if url_contains("github.com"):
        score += 5  # Open-source license (assumption: GitHub implies open-source)
        notes.append("Code available on GitHub (assumed open-source license).")
    elif url_contains("zenodo.org") or url_contains("figshare.com") or url_contains("doi.org"):
        score += 2  # Data/artifact repository, might contain code or links to code
        notes.append("Artifact on data repository (potential for code).")
    else:
        notes.append("Code availability uncertain from URL.")

    # Docker/Containerization (10 points): Requires manual check
    notes.append("Docker/Containerization: Requires manual check of the repository.")

    # Dependency Management (10 points): Requires manual check
    notes.append("Dependency Management: Requires manual check of the repository.")

    # Build Instructions (10 points): Requires manual check
    notes.append("Build Instructions: Requires manual check of the repository README.")

    # Specialized Hardware Support (5 points): Requires manual check
    notes.append("Specialized Hardware Support: Requires manual check of the repository.")

    # 1.2 Reproducibility Testing
    # CI/CD Pipelines (5 points): Cannot be inferred from URL
    notes.append("CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.")

    # Version Control (5 points): Assumed if on GitHub
    if url_contains("github.com"):
        score += 5
        notes.append("Version Control: Assumed via GitHub.")
    else:
        notes.append("Version Control: Uncertain from URL.")

    # 2. Documentation & Transparency (30 points)
    # 2.1 Artifact Documentation
    # Comprehensive README (10 points): Requires manual check
    notes.append("Comprehensive README: Requires manual check of the repository.")

    # API/Data Schema Docs (5 points): Requires manual check
    notes.append("API/Data Schema Docs: Requires manual check of the repository.")

    # Reproducibility Badge (5 points): Cannot be inferred from URL
    notes.append("Reproducibility Badge: Cannot be inferred from URL. Requires manual check.")

    # 2.2 Reproducibility Claims
    # Runtime Instructions (5 points): Requires manual check
    notes.append("Runtime Instructions: Requires manual check of the repository.")

    # Result Validation (5 points): Requires manual check
    notes.append("Result Validation: Requires manual check of the repository.")

    # 3. Data & Model Reuse (20 points)
    # 3.1 Data Accessibility
    # Public Dataset Links (10 points): If Zenodo/Figshare/DOI, assume data is accessible
    if url_contains("zenodo.org") or url_contains("figshare.com") or url_contains("doi.org"):
        score += 10
        notes.append("Public Dataset Links: Data likely accessible via data repository.")
    else:
        notes.append("Public Dataset Links: Data accessibility uncertain from URL.")

    # Data Preprocessing (5 points): Requires manual check
    notes.append("Data Preprocessing: Requires manual check of the repository.")

    # Model Weights (5 points): Requires manual check
    notes.append("Model Weights: Requires manual check of the repository.")

    # 4. Community Engagement (10 points)
    # Issue Tracking (5 points): Assumed if on GitHub
    if url_contains("github.com"):
        score += 5
        notes.append("Issue Tracking: Assumed via GitHub.")
    else:
        notes.append("Issue Tracking: Uncertain from URL.")

    # Discussion Forum (5 points): Cannot be inferred from URL
    notes.append("Discussion Forum: Cannot be inferred from URL. Requires manual check.")

    return {"score": score, "notes": notes}

if __name__ == "__main__":
    # Load the extracted papers data
    try:
        with open("papers_data.json", "r", encoding="utf-8") as f:
            papers = json.load(f)
    except FileNotFoundError:
        print("Error: papers_data.json not found. Please run extract_papers.py first.")
        papers = []

    scored_papers = []
    for paper in papers:
        evaluation = score_paper(paper)
        paper["reproducibility_score"] = evaluation["score"]
        paper["reproducibility_notes"] = evaluation["notes"]
        scored_papers.append(paper)

    # Save the scored papers to a new JSON file
    with open("scored_papers.json", "w", encoding="utf-8") as f:
        json.dump(scored_papers, f, indent=4)

    print(f"Evaluated {len(scored_papers)} papers. Results saved to scored_papers.json")

    # Print a summary of top 5 scored papers
    print("\nTop 5 Scored Papers (based on automated scoring):")
    sorted_papers = sorted(scored_papers, key=lambda x: x.get("reproducibility_score", 0), reverse=True)
    for i, paper in enumerate(sorted_papers[:5]):
        # Corrected f-string to avoid SyntaxError with parentheses in title
        print("Paper {}: {} (Score: {})".format(i+1, paper.get("title"), paper.get("reproducibility_score")))
        for note in paper.get("reproducibility_notes", []):
            print(f"  - {note}")
# Out:
# Evaluated 189 papers. Results saved to scored_papers.json
#
# Top 5 Scored Papers (based on automated scoring):
# Paper 1: One Adapter for All Programming Languages?
# Adapter Tuning for Code Search and Summarization (Score: 15)
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
# Paper 2: CCRep: Learning Code Change Representations via Pre-Trained Code Model and Query Back (Score: 15)
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
# Paper 3: Keeping Pace with Ever-Increasing Data: Towards
# Continual Learning of Code Intelligence Models (Score: 15)
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
# Paper 4: Detecting JVM JIT Compiler Bugs via Exploring
# Two-Dimensional Input Spaces (Score: 15)
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
# Paper 5: JITfuzz: Coverage-guided Fuzzing for JVM
# Just-in-Time Compilers (Score: 15)
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.

# %%
import json

def generate_report(input_file, output_file):
    try:
        with open(input_file, "r", encoding="utf-8") as f:
            papers = json.load(f)
    except FileNotFoundError:
        print(f"Error: {input_file} not found.")
        return

    report_content = "# Reproducibility Scorecard Report\n\n"
    report_content += "This report summarizes the reproducibility evaluation of papers scraped from the provided website, based on the defined scorecard criteria.\n\n"

    report_content += "## All Scored Papers\n\n"
    report_content += "| Paper ID | Title | Score | Artifact URL | DOI URL |\n"
    report_content += "|---|---|---|---|---|\n"
    for paper in papers:
        title = paper.get("title", "N/A").replace("\n", " ") # Replace newlines for table formatting
        artifact_url = paper.get("artifact_url", "N/A")
        doi_url = paper.get("doi_url", "N/A")
        # Corrected line to avoid f-string syntax error
        report_content += "| {} | {} | {} | {} | {} |\n".format(paper.get("id", "N/A"), title, paper.get("reproducibility_score", "N/A"), artifact_url, doi_url)

    report_content += "\n## Detailed Evaluation Notes\n\n"
    for paper in papers:
        # Corrected line to avoid f-string syntax error
        report_content += "### Paper ID: {} - {}\n\n".format(paper.get("id", "N/A"), paper.get("title", "N/A").replace("\n", " "))
        report_content += "**Score:** {}\n\n".format(paper.get("reproducibility_score", "N/A"))
        report_content += "**Notes:**\n"
        for note in paper.get("reproducibility_notes", []):
            report_content += f"- {note}\n"
        report_content += "\n"

    report_content += "\n## Top 5 Scored Papers (Automated Scoring)\n\n"
    sorted_papers = sorted(papers, key=lambda x: x.get("reproducibility_score", 0), reverse=True)
    for i, paper in enumerate(sorted_papers[:5]):
        # Corrected line to avoid f-string syntax error
        report_content += "### {}. {} (Score: {}.0)\n\n".format(i+1, paper.get("title", "N/A").replace("\n", " "), paper.get("reproducibility_score", "N/A"))
        report_content += "**Artifact URL:** " + paper.get("artifact_url", "N/A") + "\n"
        report_content += "**DOI URL:** " + paper.get("doi_url", "N/A") + "\n\n"
        report_content += "**Notes:**\n"
        for note in paper.get("reproducibility_notes", []):
            report_content += f"- {note}\n"
        report_content += "\n"

    with open(output_file, "w", encoding="utf-8") as f:
        f.write(report_content)
    print(f"Report generated and saved to {output_file}")

if __name__ == "__main__":
    generate_report("scored_papers.json", "reproducibility_report.md")
# Out:
# Report generated and saved to reproducibility_report.md

# %%
import json

def view_all_paper_scores(file_path="scored_papers.json"):
    try:
        with open(file_path, "r", encoding="utf-8") as f:
            papers = json.load(f)
    except FileNotFoundError:
        print(f"Error: {file_path} not found. Please ensure the file exists.")
        return

    print("\n--- All Paper Scores ---")
    for paper in papers:
        title = paper.get("title", "N/A").replace("\n", " ")
        score = paper.get("reproducibility_score", "N/A")
        artifact_url = paper.get("artifact_url", "N/A")
        doi_url = paper.get("doi_url", "N/A")

        # Corrected print statements using .format() to avoid the f-string error
        print("\nPaper ID: {}".format(paper.get("id", "N/A")))
        print("Title: {}".format(title))
        print("Score: {}".format(score))
        print("Artifact URL: {}".format(artifact_url))
        print("DOI URL: {}".format(doi_url))
        print("Notes:")
        for note in paper.get("reproducibility_notes", []):
            print(f"  - {note}")
    print("\n------------------------")

if __name__ == "__main__":
    # Make sure you have the 'scored_papers.json' file in your Colab environment first
    # by running the previous scripts or uploading the file.
    view_all_paper_scores()
# Out:
# --- All Paper Scores ---
#
# Paper ID: 13
# Title: One Adapter for All Programming Languages? Adapter Tuning for Code Search and Summarization
# Score: 15
# Artifact URL: https://github.com/wangdeze18/Multilingual-Adapter-for-SE
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00013
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 14
# Title: CCRep: Learning Code Change Representations via Pre-Trained Code Model and Query Back
# Score: 15
# Artifact URL: https://github.com/ZJU-CTAG/CCRep
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00014
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 15
# Title: Keeping Pace with Ever-Increasing Data: Towards Continual Learning of Code Intelligence Models
# Score: 15
# Artifact URL: https://github.com/ReliableCoding/REPEAT
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00015
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 16
# Title: Detecting JVM JIT Compiler Bugs via Exploring Two-Dimensional Input Spaces
# Score: 15
# Artifact URL: https://github.com/CGCL-codes/JOpFuzzer
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00016
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 17
# Title: JITfuzz: Coverage-guided Fuzzing for JVM Just-in-Time Compilers
# Score: 15
# Artifact URL: https://github.com/lochnagarr/JITFuzz
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00017
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 18
# Title: Validating SMT Solvers via Skeleton Enumeration Empowered by Historical Bug-Triggering Inputs
# Score: 15
# Artifact URL: https://github.com/CGCL-codes/HistFuzz
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00018
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 19
# Title: Regression Fuzzing for Deep Learning Systems
# Score: 15
# Artifact URL: https://github.com/youhanmo/DRFuzz
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00019
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 20
# Title: Operand-Variation-Oriented Differential Analysis for Fuzzing Binding Calls in PDF Readers
# Score: 15
# Artifact URL: https://github.com/TypeOracle/TypeOracleSrc
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00020
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 22
# Title: Data Quality for Software Vulnerability Datasets
# Score: 0
# Artifact URL: https://ﬁgshare.com/articles/software/Reproduction_Package_for_Data_Quality_for_Software_Vulnerability_Datasets/20499924
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00022
# Notes:
#   - Code availability uncertain from URL.
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 23
# Title: Do code refactorings inﬂuence the merge effort?
# Score: 15
# Artifact URL: https://github.com/gems-uff/refactoring-merge
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00023
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 24
# Title: A Comprehensive Study of Real-World Bugs in Machine Learning Model Optimization
# Score: 15
# Artifact URL: https://github.com/MOB2022/MOB-dataset
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00024
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 25
# Title: Evaluating the Impact of Experimental Assumptions in Automated Fault Localization
# Score: 12
# Artifact URL: https://figshare.com/articles/conference_contribution/Debugging_Assumptions_Artifact/21786743
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00025
# Notes:
#   - Artifact on data repository (potential for code).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data likely accessible via data repository.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 26
# Title: Locating Framework-speciﬁc Crashing Faults with Compact and Explainable Candidate Set
# Score: 15
# Artifact URL: https://github.com/hanada31/CrashTracker
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00026
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 27
# Title: PExReport: Automatic Creation of Pruned Executable Cross-Project Failure Reports
# Score: 12
# Artifact URL: https://doi.org/10.5281/zenodo.7578677
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00027
# Notes:
#   - Artifact on data repository (potential for code).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data likely accessible via data repository.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 28
# Title: RAT: A Refactoring-Aware Traceability Model for Bug Localization
# Score: 15
# Artifact URL: https://github.com/feifeiniu-se/traceability
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00028
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 29
# Title: How Do We Read Formal Claims? Eye-Tracking and the Cognition of Proofs about Algorithms
# Score: 12
# Artifact URL: https://doi.org/10.5281/zenodo.7626901
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00029
# Notes:
#   - Artifact on data repository (potential for code).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data likely accessible via data repository.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 30
# Title: Which of My Assumptions are Unnecessary for Realizability and Why Should I Care?
# Score: 12
# Artifact URL: https://doi.org/10.5281/zenodo.7528202
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00030
# Notes:
#   - Artifact on data repository (potential for code).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data likely accessible via data repository.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 31
# Title: UPCY: Safely Updating Outdated Dependencies
# Score: 12
# Artifact URL: https://doi.org/10.5281/zenodo.7037673
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00031
# Notes:
#   - Artifact on data repository (potential for code).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data likely accessible via data repository.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 32
# Title: APICAD: Augmenting API Misuse Detection through Specifi cations from Code and Documents
# Score: 15
# Artifact URL: https://github.com/x2018/apicad_public
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00032
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 33
# Title: Compatibility Issue Detection for Android Apps Based on Path-Sensitive Semantic Analysis
# Score: 15
# Artifact URL: https://github.com/PSDroid2022
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00033
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 34
# Title: OSSFP: Precise and Scalable C/C++ Third-Party Library Detection using Fingerprinting Functions
# Score: 0
# Artifact URL: https://sites.google.com/view/icse2023sca
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00034
# Notes:
#   - Code availability uncertain from URL.
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 35
# Title: SMARTMARK: Software Watermarking Scheme for Smart Contracts
# Score: 12
# Artifact URL: https://doi.org/10.6084/m9.figshare.21966875.v1
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00035
# Notes:
#   - Artifact on data repository (potential for code).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data likely accessible via data repository.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 36
# Title: Turn the Rudder: A Beacon of Reentrancy Detection for Smart Contracts on Ethereum
# Score: 15
# Artifact URL: https://github.com/InPlusLab/ReentrancyStudy-Data
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00036
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 37
# Title: BSHUNTER: Detecting and Tracing Defects of Bitcoin Scripts
# Score: 15
# Artifact URL: https://github.com/InPlusLab/bshunter-btcd
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00037
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 38
# Title: Do I Belong? Modeling Sense of Virtual Community Among Linux Kernel Contributors
# Score: 12
# Artifact URL: https://figshare.com/s/5cedff387200ebc379cb
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00038
# Notes:
#   - Artifact on data repository (potential for code).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data likely accessible via data repository.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 39
# Title: Comparison and Evaluation of Clone Detection Techniques with Different Code Representations
# Score: 15
# Artifact URL: https://github.com/TACC-Code/TACC
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00039
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 40
# Title: Learning Graph-based Code Representations for Source-level Functional Similarity Detection
# Score: 15
# Artifact URL: https://github.com/jun-zeng/Tailor
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00040
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 41
# Title: The Smelly Eight: An Empirical Study on the Prevalence of Code Smells in Quantum Computing
# Score: 12
# Artifact URL: https://doi.org/10.5281/zenodo.7625865
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00041
# Notes:
#   - Artifact on data repository (potential for code).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data likely accessible via data repository.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 42
# Title: Reachable Coverage: Estimating Saturation in Fuzzing
# Score: 12
# Artifact URL: https://doi.org/10.5281/zenodo.7571359
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00042
# Notes:
#   - Artifact on data repository (potential for code).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data likely accessible via data repository.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 43
# Title: Learning Seed-Adaptive Mutation Strategies for Greybox Fuzzing
# Score: 15
# Artifact URL: https://github.com/kupl/SeamFuzz-public
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00043
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 44
# Title: Improving Java Deserialization Gadget Chain Mining via Overriding-Guided Object Generation
# Score: 15
# Artifact URL: https://github.com/GCMiner/GCMiner
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00044
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 45
# Title: Evaluating and Improving Hybrid Fuzzing
# Score: 15
# Artifact URL: https://github.com/Tricker-z/CoFuzz
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00045
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 46
# Title: Robustiﬁcation of Behavioral Designs against Environmental Deviations
# Score: 15
# Artifact URL: https://github.com/cmu-soda/fortis-core
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00046
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 47
# Title: A Qualitative Study on the Implementation Design Decisions of Developers
# Score: 12
# Artifact URL: https://doi.org/10.6084/m9.figshare.21820140
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00047
# Notes:
#   - Artifact on data repository (potential for code).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data likely accessible via data repository.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 48
# Title: BFTDETECTOR: Automatic Detection of Business Flow Tampering for Digital Content Service
# Score: 15
# Artifact URL: https://github.com/jspaper22/bftdetector
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00048
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 49
# Title: FedSlice: Protecting Federated Learning Models from Malicious Participants with Model Slicing
# Score: 12
# Artifact URL: https://zenodo.org/record/7536416#.Y9yIZOxBwUE
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00049
# Notes:
#   - Artifact on data repository (potential for code).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data likely accessible via data repository.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# ...
#
# Paper ID: 206
# Title: An Empirical Study of Pre-Trained Model Reuse in the Hugging Face Deep Learning Model Registry
# Score: 12
# Artifact URL: https://doi.org/10.5281/zenodo.7555469
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00206
# Notes:
#   - Artifact on data repository (potential for code).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data likely accessible via data repository.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 207
# Title: ContraBERT: Enhancing Code Pre-trained Models via Contrastive Learning
# Score: 0
# Artifact URL: https://sites.google.com/view/contrabert
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00207
# Notes:
#   - Code availability uncertain from URL.
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 208
# Title: DStream: A Streaming-Based Highly Parallel IFDS Framework
# Score: 15
# Artifact URL: https://github.com/DStream-project
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00208
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 209
# Title: (Partial) Program Dependence Learning
# Score: 15
# Artifact URL: https://github.com/deeppda-icse23/DeepPDA/
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00209
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 210
# Title: MirrorTaint: Practical Non-intrusive Dynamic Taint Tracking for JVM-based Microservice Systems
# Score: 15
# Artifact URL: https://github.com/MirrorTaint/MirrorTaint
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00210
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 211
# Title: V UL G EN : Realistic Vulnerability Generation Via Pattern Mining and Deep Learning
# Score: 12
# Artifact URL: https://zenodo.org/records/7569854
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00211
# Notes:
#   - Artifact on data repository (potential for code).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data likely accessible via data repository.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 212
# Title: Compatible Remediation on Vulnerabilities from Third-Party Libraries for Java Projects
# Score: 0
# Artifact URL: https://sites.google.com/view/icse23remediation
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00212
# Notes:
#   - Code availability uncertain from URL.
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 213
# Title: Automated Black-box Testing of Mass Assignment Vulnerabilities in RESTful APIs
# Score: 12
# Artifact URL: https://doi.org/10.5281/zenodo.7348518
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00213
# Notes:
#   - Artifact on data repository (potential for code).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data likely accessible via data repository.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 214
# Title: CoLeFunDa: Explainable Silent Vulnerability Fix Identification
# Score: 12
# Artifact URL: https://figshare.com/s/840e1fb94bd972829c80
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00214
# Notes:
#   - Artifact on data repository (potential for code).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data likely accessible via data repository.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 215
# Title: Finding Causally Different Tests for an Industrial Control System
# Score: 15
# Artifact URL: https://github.com/yuqiChen94/Causally-Different-Attacks/
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00215
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 216
# Title: Doppelg ¨anger Test Generation for Revealing Bugs in Autonomous Driving Software
# Score: 12
# Artifact URL: https://doi.org/10.5281/zenodo.7575582
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00216
# Notes:
#   - Artifact on data repository (potential for code).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Uncertain from URL.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data likely accessible via data repository.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Uncertain from URL.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# Paper ID: 217
# Title: Generating Realistic and Diverse Tests for LiDAR-Based Perception Systems
# Score: 15
# Artifact URL: https://github.com/less-lab-uva/semLidarFuzz
# DOI URL: https://doi.org/10.1109/ICSE48619.2023.00217
# Notes:
#   - Code available on GitHub (assumed open-source license).
#   - Docker/Containerization: Requires manual check of the repository.
#   - Dependency Management: Requires manual check of the repository.
#   - Build Instructions: Requires manual check of the repository README.
#   - Specialized Hardware Support: Requires manual check of the repository.
#   - CI/CD Pipelines: Cannot be inferred from URL. Requires manual check.
#   - Version Control: Assumed via GitHub.
#   - Comprehensive README: Requires manual check of the repository.
#   - API/Data Schema Docs: Requires manual check of the repository.
#   - Reproducibility Badge: Cannot be inferred from URL. Requires manual check.
#   - Runtime Instructions: Requires manual check of the repository.
#   - Result Validation: Requires manual check of the repository.
#   - Public Dataset Links: Data accessibility uncertain from URL.
#   - Data Preprocessing: Requires manual check of the repository.
#   - Model Weights: Requires manual check of the repository.
#   - Issue Tracking: Assumed via GitHub.
#   - Discussion Forum: Cannot be inferred from URL. Requires manual check.
#
# ------------------------

# %%
import os
import requests

def check_file_exists(repo_path, filename):
    return os.path.isfile(os.path.join(repo_path, filename))

def check_github_ci(repo_path):
    return os.path.isdir(os.path.join(repo_path, '.github', 'workflows'))

def check_github_issues(repo_owner, repo_name):
    url = f"https://api.github.com/repos/{repo_owner}/{repo_name}"
    response = requests.get(url)
    data = response.json()
    return data.get("has_issues", False)

# Example usage for a local clone of a GitHub repo
repo_path = "/path/to/cloned/repo"
print("README:", check_file_exists(repo_path, "README.md"))
print("Dockerfile:", check_file_exists(repo_path, "Dockerfile"))
print("Dependencies:", check_file_exists(repo_path, "requirements.txt"))
print("CI/CD:", check_github_ci(repo_path))
print("License:", check_file_exists(repo_path, "LICENSE"))
# Out:
# README: False
# Dockerfile: False
# Dependencies: False
# CI/CD: False
# License: False

# %%
import json
import requests
from urllib.parse import urlparse

# List of files/folders to check for reproducibility
CHECK_FILES = [
    "README.md",
    "Dockerfile",
    "requirements.txt",
    "environment.yml",
    "Pipfile",
    ".github/workflows",  # For CI/CD
    "LICENSE",
    "setup.py"
]

def get_github_repo_info(artifact_url):
    """
    Extracts owner and repo name from a GitHub URL.
    """
    try:
        parsed = urlparse(artifact_url)
        if "github.com" not in parsed.netloc:
            return None, None
        parts = parsed.path.strip("/").split("/")
        if len(parts) < 2:
            return None, None
        return parts[0], parts[1]
    except Exception:
        return None, None

def github_file_exists(owner, repo, path):
    """
    Checks if a file or folder exists in the root of the GitHub repo using the GitHub API.
    """
    api_url = f"https://api.github.com/repos/{owner}/{repo}/contents/{path}"
    response = requests.get(api_url)
    return response.status_code == 200

def check_github_files(artifact_url):
    """
    Checks for the presence of key reproducibility files in a GitHub repo.
    Returns a dict {filename: exists (bool)}
    """
    owner, repo = get_github_repo_info(artifact_url)
    if not owner or not repo:
        return {}
    results = {}
    for filename in CHECK_FILES:
        exists = github_file_exists(owner, repo, filename)
        results[filename] = exists
    return results

if __name__ == "__main__":
    # Load paper data
    with open("papers_data.json", "r", encoding="utf-8") as f:
        papers = json.load(f)

    for paper in papers:
        artifact_url = paper.get("artifact_url", "")
        if "github.com" in artifact_url:
            file_status = check_github_files(artifact_url)
            paper["github_file_check"] = file_status
        else:
            paper["github_file_check"] = {}

    # Save results
    with open("papers_file_checked.json", "w", encoding="utf-8") as f:
        json.dump(papers, f, indent=2)

    print("Checked files for all GitHub repositories and saved to papers_file_checked.json")
# Out:
# Checked files for all GitHub repositories and saved to papers_file_checked.json

# %%
import json

with open("papers_file_checked.json", "r", encoding="utf-8") as f:
    papers = json.load(f)

for paper in papers:
    print(f"Paper: {paper.get('title')}")
    for fname, exists in paper.get("github_file_check", {}).items():
        print(f"  {fname}: {'Found' if exists else 'Not found'}")
    print("-" * 40)
# Out:
# Paper: One Adapter for All Programming Languages?
# Adapter Tuning for Code Search and Summarization
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: CCRep: Learning Code Change Representations via Pre-Trained Code Model and Query Back
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Found
#   setup.py: Not found
# ----------------------------------------
# Paper: Keeping Pace with Ever-Increasing Data: Towards
# Continual Learning of Code Intelligence Models
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Detecting JVM JIT Compiler Bugs via Exploring
# Two-Dimensional Input Spaces
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Found
#   setup.py: Not found
# ----------------------------------------
# Paper: JITfuzz: Coverage-guided Fuzzing for JVM
# Just-in-Time Compilers
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Validating SMT Solvers via Skeleton Enumeration
# Empowered by Historical Bug-Triggering Inputs
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Found
#   setup.py: Not found
# ----------------------------------------
# Paper: Regression Fuzzing for Deep Learning Systems
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Found
#   setup.py: Not found
# ----------------------------------------
# Paper: Operand-Variation-Oriented Differential Analysis for Fuzzing Binding Calls in PDF Readers
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Found
#   setup.py: Not found
# ----------------------------------------
# Paper: Data Quality for Software Vulnerability Datasets
# ----------------------------------------
# Paper: Do code refactorings inﬂuence the merge effort?
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Found
# ----------------------------------------
# Paper: A Comprehensive Study of Real-World Bugs
# in Machine Learning Model Optimization
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Found
#   setup.py: Not found
# ----------------------------------------
# Paper: Evaluating the Impact of Experimental Assumptions in Automated Fault Localization
# ----------------------------------------
# Paper: Locating Framework-speciﬁc Crashing Faults with
# Compact and Explainable Candidate Set
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: PExReport: Automatic Creation of Pruned
# Executable Cross-Project Failure Reports
# ----------------------------------------
# Paper: RAT: A Refactoring-Aware Traceability Model for
# Bug Localization
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: How Do We Read Formal Claims? Eye-Tracking
# and the Cognition of Proofs about Algorithms
# ----------------------------------------
# Paper: Which of My Assumptions are Unnecessary for
# Realizability and Why Should I Care?
# ----------------------------------------
# Paper: UPCY: Safely Updating Outdated Dependencies
# ----------------------------------------
# Paper: APICAD: Augmenting API Misuse Detection
# through Specifi cations from Code and Documents
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Found
#   setup.py: Not found
# ----------------------------------------
# Paper: Compatibility Issue Detection for Android Apps
# Based on Path-Sensitive Semantic Analysis
# ----------------------------------------
# Paper: OSSFP: Precise and Scalable C/C++ Third-Party
# Library Detection using Fingerprinting Functions
# ----------------------------------------
# Paper: SMARTMARK: Software Watermarking Scheme for Smart Contracts
# ----------------------------------------
# Paper: Turn the Rudder: A Beacon of Reentrancy
# Detection for Smart Contracts on Ethereum
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Found
#   setup.py: Not found
# ----------------------------------------
# Paper: BSHUNTER: Detecting and Tracing Defects of
# Bitcoin Scripts
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Do I Belong? Modeling Sense of Virtual Community Among Linux Kernel Contributors
# ----------------------------------------
# Paper: Comparison and Evaluation of Clone Detection
# Techniques with Different Code Representations
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Learning Graph-based Code Representations for
# Source-level Functional Similarity Detection
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: The Smelly Eight: An Empirical Study on the
# Prevalence of Code Smells in Quantum Computing
# ----------------------------------------
# Paper: Reachable Coverage: Estimating Saturation in Fuzzing
# ----------------------------------------
# Paper: Learning Seed-Adaptive Mutation Strategies for
# Greybox Fuzzing
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Improving Java Deserialization Gadget Chain
# Mining via Overriding-Guided Object Generation
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Evaluating and Improving Hybrid Fuzzing
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Robustiﬁcation of Behavioral Designs against
# Environmental Deviations
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: A Qualitative Study on the Implementation Design
# Decisions of Developers
# ----------------------------------------
# Paper: BFTDETECTOR: Automatic Detection of Business Flow Tampering for Digital Content Service
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: FedSlice: Protecting Federated Learning Models from Malicious Participants with Model Slicing
# ----------------------------------------
# Paper: PTPDroid: Detecting Violated User Privacy Disclosures to Third-Parties of Android Apps
# ----------------------------------------
# Paper: AdHere: Automated Detection and Repair of Intrusive Ads
# ----------------------------------------
# Paper: Bad Snakes: Understanding and Improving Python Package Index Malware Scanning
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: FedDebug: Systematic Debugging for Federated Learning Applications
# ----------------------------------------
# Paper: CrossCodeBench: Benchmarking Cross-Task Generalization of Source Code Models
# ----------------------------------------
# Paper: ECSTATIC: An Extensible Framework for Testing and Debugging Configurable Static Analysis
# ----------------------------------------
# Paper: Responsibility in Context: On Applicability of Slicing in Semantic Regression Analysis
# ----------------------------------------
# Paper: Does the Stream API Benefit from Special Debugging Facilities? A Controlled Experiment on Loops and Streams with Specific Debugger
# ----------------------------------------
# Paper: F ONTE : Finding Bug Inducing Commits from Failures
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Found
#   setup.py: Not found
# ----------------------------------------
# Paper: RepresentThemAll: A Universal Learning Representation of Bug Reports
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Found
#   setup.py: Not found
# ----------------------------------------
# Paper: Demystifying Exploitable Bugs in Smart Contracts
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Found
#   LICENSE: Found
#   setup.py: Not found
# ----------------------------------------
# Paper: Understanding and Detecting On-the-Fly Configuration Bugs
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Explaining Software Bugs Leveraging Code Structures in Neural Machine Translation
# ----------------------------------------
# Paper: Is It Enough to Recommend Tasks to Newcomers? Understanding Mentoring on Good First Issues
# ----------------------------------------
# Paper: From Organizations to Individuals: Psychoactive Substance Use By Professional Programmers
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: On the Self-Governance and Episodic Changes in Apache Incubator Projects: An Empirical Study
# ----------------------------------------
# Paper: Socio-Technical Anti-Patterns in Building ML-Enabled Software
# ----------------------------------------
# Paper: Moving on from the software engineers’ gambit: an approach to support the defense of software effort estimates
# ----------------------------------------
# Paper: Concrat: An Automatic C-to-Rust Lock API Translator for Concurrent Programs
# ----------------------------------------
# Paper: Triggers for Reactive Synthesis Specifications
# ----------------------------------------
# Paper: Using Reactive Synthesis: An End-to-End Exploratory Case Study
# ----------------------------------------
# Paper: Developer-Intent Driven Code Comment Generation
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Data Quality Matters: A Case Study of Obsolete Comment Detection
#   README.md: Found
#   Dockerfile: Not found
#   requirements.txt: Found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Revisiting Learning-based Commit Message Generation
# ----------------------------------------
# Paper: Commit Message Matters: Investigating Impact and Evolution of Commit Message Quality
# ----------------------------------------
# Paper: PILAR: Studying and Mitigating the Influence of Configurations on Log Parsing
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Did We Miss Something Important? Studying and Exploring Variable-Aware Log Abstraction
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: On the Temporal Relations between Logging and Code
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: When to Say What: Learning to Find Condition-Message Inconsistencies
# ----------------------------------------
# Paper: SemParser: A Semantic Parser for Log Analytics
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: BADGE: Prioritizing UI Events with Hierarchical Multi-Armed Bandits for Automated UI Testing
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Efficiency Matters: Speeding Up Automated Testing with GUI Rendering Inference
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: C ODA M OSA : Escaping Coverage Plateaus in Test Generation with Pre-trained Large Language Models
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: TAINT M INI : Detecting Flow of Sensitive Data in Mini-Programs with Static Taint Analysis
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: AChecker: Statically Detecting Smart Contract Access Control Vulnerabilities
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Fine-grained Commit-level Vulnerability Type Prediction by CWE Tree Structure
# ----------------------------------------
# Paper: Silent Vulnerable Dependency Alert Prediction with Vulnerability Key Aspect Explanation
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Reusing Deep Neural Network Models through Model Re-engineering
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: P Y E VOLVE : Automating Frequent Code Changes in Python ML Systems
# ----------------------------------------
# Paper: Decomposing a Recurrent Neural Network into Modules for Enabling Reusability and Replacement
# ----------------------------------------
# Paper: CHRONOS: Time-Aware Zero-Shot Identification of Libraries from Vulnerability Reports
# ----------------------------------------
# Paper: Understanding the Threats of Upstream Vulnerabilities to Downstream Projects in the Maven Ecosystem
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Found
#   setup.py: Not found
# ----------------------------------------
# Paper: S EC B ENCH . JS : An Executable Security Benchmark Suite for Server-Side JavaScript
#   README.md: Found
#   Dockerfile: Found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: On Privacy Weaknesses and Vulnerabilities in Software Systems
# ----------------------------------------
# Paper: Detecting Exception Handling Bugs in C++ Programs
# ----------------------------------------
# Paper: Learning to Boost Disjunctive Static Bug-Finders
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Detecting Isolation Bugs via Transaction Oracle Construction
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: SmallRace: Static Race Detection for Dynamic Languages - A Case on Smalltalk
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: “STILL AROUND”: Experiences and Survival Strategies of Veteran Women Software Developers
# ----------------------------------------
# Paper: When and Why Test Generators for Deep Learning Produce Invalid Inputs: an Empirical Study
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Fuzzing Automatic Differentiation in Deep-Learning Libraries
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Lightweight Approaches to DNN Regression Error Reduction: An Uncertainty Alignment Perspective
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Revisiting Neuron Coverage for DNN Testing: A Layer-Wise and Distribution-Aware Criterion
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Code Review of Build System Specifications: Prevalence, Purposes, Patterns, and Perceptions
# ----------------------------------------
# Paper: Better Automatic Program Repair by Using Bug Reports and Tests Together
# ----------------------------------------
# Paper: CCT EST : Testing and Repairing Code Completion Systems
# ----------------------------------------
# Paper: KNOD: Domain Knowledge Distilled Tree Decoder for Automated Program Repair
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Rete: Learning Namespace Representation for Program Repair
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: AI-based Question Answering Assistance for Analyzing Natural-language Requirements
# ----------------------------------------
# Paper: Strategies, Benefits and Challenges of App Store-inspired Requirements Elicitation
# ----------------------------------------
# Paper: Compiling Parallel Symbolic Execution with Continuations
# ----------------------------------------
# Paper: Verifying Data Constraint Equivalence in FinTech Systems
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Fill in the Blank: Context-aware Automated Text Input Generation for Mobile GUI Testing
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Detecting Dialog-Related Keyboard Navigation Failures in Web Applications
# ----------------------------------------
# Paper: C OLUMBUS : Android App Testing Through Systematic Callback Exploration
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: GameRTS: A Regression Testing Framework for Video Games
# ----------------------------------------
# Paper: Flexible and Optimal Dependency Management via Max-SMT
# ----------------------------------------
# Paper: Impact of Code Language Models on Automated Program Repair
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Tare: Type-Aware Neural Program Repair
# ----------------------------------------
# Paper: Template-based Neural Program Repair
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Automated Repair of Programs from Large Language Models
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Testability Refactoring in Pull Requests: Patterns and Trends
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Usability-Oriented Design of Liquid Types for Java
# ----------------------------------------
# Paper: Towards Understanding Fairness and its Composition in Ensemble Machine Learning
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Fairify: Fairness Verification of Neural Networks
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Leveraging Feature Bias for Scalable Misprediction Explanation of Machine Learning Models
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Information-Theoretic Testing and Debugging of Fairness Defects in Deep Neural Networks
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Demystifying Privacy Policy of Third-Party Libraries in Mobile Apps
# ----------------------------------------
# Paper: Cross-Domain Requirements Linking via Adversarial-based Domain Adaptation
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: What Challenges Do Developers Face About Checked-in Secrets in Software Artifacts?
# ----------------------------------------
# Paper: Lejacon: A Lightweight and Efficient Approach to Java Confidential Computing on SGX
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Keyword Extraction From Specification Documents for Planning Security Mechanisms
# ----------------------------------------
# Paper: Dependency Facade: The Coupling and Conflicts between Android Framework and Its Customization
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Test Selection for Unified Regression Testing
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: ATM: Black-box Test Case Minimization based on Test Code Similarity and Evolutionary Search
# ----------------------------------------
# Paper: Measuring and Mitigating Gaps in Structural Testing
# ----------------------------------------
# Paper: Heterogeneous Anomaly Detection for Software Systems via Semi-supervised Cross-modal Attention
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Eadro: An End-to-End Troubleshooting Framework for Microservices on Multi-source Data
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: LogReducer: Identify and Reduce Log Hotspots in Kernel on the Fly
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Aries: Efficient Testing of Deep Neural Networks via Labeling-Free Accuracy Estimation
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: CC: Causality-Aware Coverage Criterion for Deep Neural Networks
# ----------------------------------------
# Paper: Balancing Effectiveness and Flakiness of Non-Deterministic Machine Learning Tests
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Many-Objective Reinforcement Learning for Online Testing of DNN-Enabled Systems
# ----------------------------------------
# Paper: Reliability Assurance for Deep Neural Network Architectures Against Numerical Defects
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Automated Summarization of Stack Overflow Posts
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Semi-Automatic, Inline and Collaborative Web Page Code Curations
# ----------------------------------------
# Paper: Identifying Key Classes for Initial Software Comprehension: Can We Do It Better?
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Improving API Knowledge Discovery with ML: A Case Study of Comparable API Methods
# ----------------------------------------
# Paper: Evidence Profiles for Validity Threats in Program Comprehension Experiments
# ----------------------------------------
# Paper: Developers’ Visuo-spatial Mental Model and Program Comprehension
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Two Sides of the Same Coin: Exploiting the Impact of Identifiers in Neural Code Comprehension
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: SeeHow: Workflow Extraction from Programming Screencasts through Action-Aware Video Analytics
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: AidUI: Toward Automated Recognition of Dark Patterns in User Interfaces
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Carving UI Tests to Generate API Tests and API Specification
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Ex pede Herculem: Augmenting Activity Transition Graph for Apps via Graph Convolution Network
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Sustainability is Stratified: Toward a Better Theory of Sustainable Software Engineering
# ----------------------------------------
# Paper: DLInfer: Deep Learning with Static Slicing for Python Type Inference
# ----------------------------------------
# Paper: ViolationTracker: Building Precise Histories for Static Analysis Violations
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Compiler Test-Program Generation via Memoized Configuration Search
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Testing Database Engines via Query Plan Guidance
# ----------------------------------------
# Paper: Testing Database Systems via Differential Query Execution
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Analyzing the Impact of Workloads on Modeling the Performance of Configurable Software Systems
# ----------------------------------------
# Paper: Twins or False Friends? A Study on Energy Consumption and Performance of Configurable Software
# ----------------------------------------
# Paper: Learning Deep Semantics for Test Completion
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: S K C ODER : A Sketch-based Approach for Automatic Code Generation
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: An Empirical Comparison of Pre-Trained Models of Source Code
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: On the Robustness of Code Generation Techniques: An Empirical Study on GitHub Copilot
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Source Code Recommender Systems: The Practitioners’ Perspective
# ----------------------------------------
# Paper: Safe Low-Level Code Without Overhead is Practical
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Sibyl: Improving Software Engineering Tools with SMT Selection
# ----------------------------------------
# Paper: CoCoSoDa: Effective Contrastive Learning for Code Search
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Coverage Guided Fault Injection for Cloud Systems
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: D IVER : Oracle-Guided SMT Solver Testing with Unrestricted Random Mutations
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: An Empirical Study of Deep Learning Models for Vulnerability Detection
# ----------------------------------------
# Paper: DeepVD: Toward Class-Separation Features for Neural Network Vulnerability Detection
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Enhancing Deep Learning-based Vulnerability Detection by Building Behavior Graph Model
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Vulnerability Detection with Graph Simplification and Enhanced Graph Representation Learning
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Does data sampling improve deep learning-based vulnerability detection? Yeas! and Nays!
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Incident-aware Duplicate Ticket Aggregation for Cloud Systems
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Large Language Models are Few-shot Testers: Exploring LLM-based General Bug Reproduction
# ----------------------------------------
# Paper: On the Reproducibility of Software Defect Datasets
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Context-aware Bug Reproduction for Mobile Apps
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Read It, Don’t Watch It: Captioning Bug Recordings Automatically
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: D UET CS: Code Style Transfer through Generation and Retrieval
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: On the Applicability of Language Models to Block-Based Programs
# ----------------------------------------
# Paper: MTTM: Metamorphic Testing for Textual Content Moderation Software
# ----------------------------------------
# Paper: Metamorphic Shader Fusion for Testing Graphics Shader Compilers
# ----------------------------------------
# Paper: MorphQ: Metamorphic Testing of the Qiskit Quantum Computing Platform
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Automating Code-Related Tasks Through Transformers: The Impact of Pre-training
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Log Parsing with Prompt-based Few-shot Learning
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Retrieval-Based Prompt Selection for Code-Related Few-Shot Learning
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: An Empirical Study of Pre-Trained Model Reuse in the Hugging Face Deep Learning Model Registry
# ----------------------------------------
# Paper: ContraBERT: Enhancing Code Pre-trained Models via Contrastive Learning
# ----------------------------------------
# Paper: DStream: A Streaming-Based Highly Parallel IFDS Framework
# ----------------------------------------
# Paper: (Partial) Program Dependence Learning
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: MirrorTaint: Practical Non-intrusive Dynamic Taint Tracking for JVM-based Microservice Systems
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: V UL G EN : Realistic Vulnerability Generation Via Pattern Mining and Deep Learning
# ----------------------------------------
# Paper: Compatible Remediation on Vulnerabilities from Third-Party Libraries for Java Projects
# ----------------------------------------
# Paper: Automated Black-box Testing of Mass Assignment Vulnerabilities in RESTful APIs
# ----------------------------------------
# Paper: CoLeFunDa: Explainable Silent Vulnerability Fix Identification
# ----------------------------------------
# Paper: Finding Causally Different Tests for an Industrial Control System
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
# Paper: Doppelg ¨anger Test Generation for Revealing Bugs in Autonomous Driving Software
# ----------------------------------------
# Paper: Generating Realistic and Diverse Tests for LiDAR-Based Perception Systems
#   README.md: Not found
#   Dockerfile: Not found
#   requirements.txt: Not found
#   environment.yml: Not found
#   Pipfile: Not found
#   .github/workflows: Not found
#   LICENSE: Not found
#   setup.py: Not found
# ----------------------------------------
